# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # MLP

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Vấn đề của MLP:<br>
#     + Bỏ qua thông tin không gian -> đưa vào model một vector -> data trở nên phức tạp hơn <br>
#     + Chỉ có thể xử lí với data nhỏ, dữ liệu đơn giản <br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Flaten: phá vỡ thông tin không gian

# %% [markdown]
# Giải quyết vấn đề của MLP bằng cách sử dụng CNN

# %% [markdown]
# ![image.png](attachment:image.png)
